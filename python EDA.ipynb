# %% [markdown]
# # Data Loading and Cleaning

# %%
# import the libraries for analysis

import numpy as np
import pandas as pd

# %%
# Loading the data from a csv file

# df1 = pd.read_csv(r"C:\Users\Lenovo\Desktop\SQL\Chinook\Python\Rich Tutorials\Clark U project\adult 1.csv")
df1 = pd.read_csv(r"C:\Users\Lenovo\Desktop\SQL\Chinook\Python\Rich Tutorials\Clark U project\adult.csv")

df2 = pd.read_csv(r"C:\Users\Lenovo\Desktop\SQL\Chinook\Python\Rich Tutorials\Clark U project\adult 1.csv")

# %%
# Renaming the columns

columns = [
    "Age", 
    "Workclass", 
    "fnlwgt", 
    "Education", 
    "Education Number", 
    "Marital Status", 
    "Occupation", 
    "Relationship", 
    "Race", 
    "Sex", 
    "Capital Gain", 
    "Capital Loss", 
    "Hours per Week", 
    "Native Country", 
    "Income"
]

# %%
# Dataframe1 renamed columns

df1.columns = columns

# %%
df1.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education Number  \
# 0   50   Self-emp-not-inc   83311   Bachelors                13
# 1   38            Private  215646     HS-grad                 9
# 2   53            Private  234721        11th                 7
# 3   28            Private  338409   Bachelors                13
# 4   37            Private  284582     Masters                14
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital Gain  Capital Loss  Hours per Week  Native Country  Income
# ...

# %%
# combining dataframes to ensure both dataframes have the same structure. 

df2.columns = df1.columns

# %%
# the first 5 rows of df2

df2.head()
# Out:
#    Age   Workclass  fnlwgt      Education  Education Number  \
# 0   25     Private  226802           11th                 7
# 1   38     Private   89814        HS-grad                 9
# 2   28   Local-gov  336951     Assoc-acdm                12
# 3   44     Private  160323   Some-college                10
# 4   18           ?  103497   Some-college                10
#
#         Marital Status          Occupation Relationship    Race      Sex  \
# 0        Never-married   Machine-op-inspct    Own-child   Black     Male
# 1   Married-civ-spouse     Farming-fishing      Husband   White     Male
# 2   Married-civ-spouse     Protective-serv      Husband   White     Male
# 3   Married-civ-spouse   Machine-op-inspct      Husband   Black     Male
# 4        Never-married                   ?    Own-child   White   Female
#
#    Capital Gain  Capital Loss  Hours per Week  Native Country   Income
# 0             0             0              40   United-States   <=50K.
# ...

# %%
# Searching for missing data (?) for df2

df2 = df2.applymap(lambda x: x.strip() if isinstance(x, str) else x)

question_mark_count = (df2 == '?').sum()
question_mark_count
# Out:
# Age                   0
# Workclass           963
# fnlwgt                0
# Education             0
# Education Number      0
# Marital Status        0
# Occupation          966
# Relationship          0
# Race                  0
# Sex                   0
# Capital Gain          0
# Capital Loss          0
# Hours per Week        0
# Native Country      274
# Income                0
# dtype: int64

# %%
# Searching for missing data (?) in df 1

df1 = df1.applymap(lambda x: x.strip() if isinstance(x, str) else x)

question_mark_count = (df1 == '?').sum()
question_mark_count
# Out:
# Age                    0
# Workclass           1836
# fnlwgt                 0
# Education              0
# Education Number       0
# Marital Status         0
# Occupation          1843
# Relationship           0
# Race                   0
# Sex                    0
# Capital Gain           0
# Capital Loss           0
# Hours per Week         0
# Native Country       583
# Income                 0
# dtype: int64

# %%
# Concatenating df1 and df 2

data = pd.concat([df1, df2], ignore_index=True )  
data.head()
# Out:
#    Age         Workclass  fnlwgt  Education  Education Number  \
# 0   50  Self-emp-not-inc   83311  Bachelors                13
# 1   38           Private  215646    HS-grad                 9
# 2   53           Private  234721       11th                 7
# 3   28           Private  338409  Bachelors                13
# 4   37           Private  284582    Masters                14
#
#        Marital Status         Occupation   Relationship   Race     Sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    Capital Gain  Capital Loss  Hours per Week Native Country Income
# 0             0             0              13  United-States  <=50K
# ...

# %%
#showing the last 5 list of the data

data.tail()
# Out:
#        Age     Workclass  fnlwgt  Education  Education Number  \
# 48835   33       Private  245211  Bachelors                13
# 48836   39       Private  215419  Bachelors                13
# 48838   38       Private  374983  Bachelors                13
# 48839   44       Private   83891  Bachelors                13
# 48840   35  Self-emp-inc  182148  Bachelors                13
#
#            Marital Status       Occupation   Relationship                Race  \
# 48835       Never-married   Prof-specialty      Own-child               White
# 48836            Divorced   Prof-specialty  Not-in-family               White
# 48838  Married-civ-spouse   Prof-specialty        Husband               White
# 48839            Divorced     Adm-clerical      Own-child  Asian-Pac-Islander
# 48840  Married-civ-spouse  Exec-managerial        Husband               White
#
#           Sex  Capital Gain  Capital Loss  Hours per Week Native Country  \
# ...

# %% [markdown]
# # Data Exploration

# %%
# checking the number of rows and columns

data.shape
# Out:
# (48841, 15)

# %%
# checking for missing data(?) in both dataframe

data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x)

question_mark_count = (data == '?').sum()
question_mark_count
# Out:
# Age                    0
# Workclass           2799
# fnlwgt                 0
# Education              0
# Education Number       0
# Marital Status         0
# Occupation          2809
# Relationship           0
# Race                   0
# Sex                    0
# Capital Gain           0
# Capital Loss           0
# Hours per Week         0
# Native Country       857
# Income                 0
# dtype: int64

# %%
 #Replace question marks with NaN
import numpy as np
data.replace('?', np.nan, inplace=True)

# %%
# checking for null values in the data

data.isna().sum()
# Out:
# Age                    0
# Workclass           2799
# fnlwgt                 0
# Education              0
# Education Number       0
# Marital Status         0
# Occupation          2809
# Relationship           0
# Race                   0
# Sex                    0
# Capital Gain           0
# Capital Loss           0
# Hours per Week         0
# Native Country       857
# Income                 0
# dtype: int64

# %%
# Drop null values

data = data.dropna()

# %%
# describing the data

data.describe()
# Out:
#                 Age        fnlwgt  Education Number  Capital Gain  \
# count  45221.000000  4.522100e+04      45221.000000  45221.000000
# mean      38.547931  1.897372e+05         10.118396   1101.406625
# std       13.218016  1.056390e+05          2.552873   7506.511388
# min       17.000000  1.349200e+04          1.000000      0.000000
# 25%       28.000000  1.173920e+05          9.000000      0.000000
# 50%       37.000000  1.783190e+05         10.000000      0.000000
# 75%       47.000000  2.379280e+05         13.000000      0.000000
# max       90.000000  1.490400e+06         16.000000  99999.000000
#
#        Capital Loss  Hours per Week
# count  45221.000000    45221.000000
# mean      88.597377       40.938038
# std      404.960355       12.007640
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
#summary of the dataframe

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45221 entries, 0 to 48840
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               45221 non-null  int64
#  1   Workclass         45221 non-null  object
#  2   fnlwgt            45221 non-null  int64
#  3   Education         45221 non-null  object
#  4   Education Number  45221 non-null  int64
#  5   Marital Status    45221 non-null  object
#  6   Occupation        45221 non-null  object
#  7   Relationship      45221 non-null  object
#  8   Race              45221 non-null  object
#  9   Sex               45221 non-null  object
#  10  Capital Gain      45221 non-null  int64
#  11  Capital Loss      45221 non-null  int64
#  12  Hours per Week    45221 non-null  int64
#  13  Native Country    45221 non-null  object
#  14  Income            45221 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.5+ MB

# %%
# Checking for all the Unique values in attributes

for column in data.columns:
    unique_values = data[column].unique()
    print(f"Unique values in '{column}': {unique_values}\n")
# Out:
# Unique values in 'Age': [50 38 53 28 37 49 52 31 42 30 23 32 34 25 43 40 54 35 59 56 19 39 20 45
#  22 48 21 24 57 44 41 29 47 46 36 79 27 18 33 76 55 61 70 64 71 66 51 58
#  26 17 60 90 75 65 77 62 63 67 74 72 69 68 73 81 78 88 80 84 83 85 82 86
#  89 87]
#
# Unique values in 'Workclass': ['Self-emp-not-inc' 'Private' 'State-gov' 'Federal-gov' 'Local-gov'
#  'Self-emp-inc' 'Without-pay']
#
# Unique values in 'fnlwgt': [ 83311 215646 234721 ... 173449  89686 350977]
#
# Unique values in 'Education': ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  '7th-8th' 'Doctorate' 'Assoc-voc' 'Prof-school' '5th-6th' '10th'
#  'Preschool' '12th' '1st-4th']
#
# Unique values in 'Education Number': [13  9  7 14  5 10 12  4 16 11 15  3  6  1  8  2]
#
# Unique values in 'Marital Status': ['Married-civ-spouse' 'Divorced' 'Married-spouse-absent' 'Never-married'
#  'Separated' 'Married-AF-spouse' 'Widowed']
#
# ...

# %%
# Checking for the unique values

unique_values = data.nunique()
unique_values
# Out:
# Age                    74
# Workclass               7
# fnlwgt              26740
# Education              16
# Education Number       16
# Marital Status          7
# Occupation             14
# Relationship            6
# Race                    5
# Sex                     2
# Capital Gain          121
# Capital Loss           97
# Hours per Week         96
# Native Country         41
# Income                  4
# dtype: int64

# %%
# Copying the new data without null values

newdata = data.copy()
newdata.head()
# Out:
#    Age         Workclass  fnlwgt  Education  Education Number  \
# 0   50  Self-emp-not-inc   83311  Bachelors                13
# 1   38           Private  215646    HS-grad                 9
# 2   53           Private  234721       11th                 7
# 3   28           Private  338409  Bachelors                13
# 4   37           Private  284582    Masters                14
#
#        Marital Status         Occupation   Relationship   Race     Sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    Capital Gain  Capital Loss  Hours per Week Native Country Income
# 0             0             0              13  United-States  <=50K
# ...

# %% [markdown]
# # Data Transformation

# %%
# This function converts categorical columns in newdata into a series of binary (0 or 1) columns

dummydata = pd.get_dummies(newdata)
dummydata
# Out:
#        Age  fnlwgt  Education Number  Capital Gain  Capital Loss  \
# 0       50   83311                13             0             0
# 1       38  215646                 9             0             0
# 2       53  234721                 7             0             0
# 3       28  338409                13             0             0
# 4       37  284582                14             0             0
# ...    ...     ...               ...           ...           ...
# 48835   33  245211                13             0             0
# 48836   39  215419                13             0             0
# 48838   38  374983                13             0             0
# 48839   44   83891                13          5455             0
# 48840   35  182148                13             0             0
#
#        Hours per Week  Workclass_Federal-gov  Workclass_Local-gov  \
# 0                  13                  False                False
# ...

# %%
 # Normalize or standardize any numerical columns (hint: consider `sklearn.preprocessing` modules). 

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# identifying all the numerical columns in the adult_data DataFrame

numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns

# %%
# scale or normalize the numerical features in the dataset to ensure that numerical features have similar ranges

data_scaler = scaler.fit_transform(data[numerical_cols])
data_scaler
# Out:
# array([[ 0.86640803, -1.00746265,  1.12878119, -0.14672845, -0.21878279,
#         -2.32671417],
#        [-0.04145382,  0.24526036, -0.43809797, -0.14672845, -0.21878279,
#         -0.07812093],
#        [ 1.09337349,  0.42583007, -1.22153755, -0.14672845, -0.21878279,
#         -0.07812093],
#        ...,
#        [-0.04145382,  1.75359245,  1.12878119, -0.14672845, -0.21878279,
#          0.75469138],
#        [ 0.4124771 , -1.0019722 ,  1.12878119,  0.579982  , -0.21878279,
#         -0.07812093],
#        [-0.26841929, -0.07184181,  1.12878119, -0.14672845, -0.21878279,
#          1.58750369]])

# %%
# Remove trailing periods ('.') from the Income column
data['Income'] = data['Income'].str.replace('.', '', regex=False)

# Verify the unique values after cleaning
print(data['Income'].value_counts())
# Out:
# Income
# <=50K    34013
# >50K     11208
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Group by the different work classes

# %%
#importing libraries for visulaization

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# checking for the values in the Income

data["Income"].value_counts()
# Out:
# Income
# <=50K    34013
# >50K     11208
# Name: count, dtype: int64

# %%
# Visualization 1: Workclass vs Income

plt.figure(figsize=(10, 6))  # Create a new figure
sns.countplot(x ='Workclass', hue ='Income', data = newdata, order = newdata['Workclass'].value_counts().index)
plt.title('Income Distribution Across Work Classes')
plt.xlabel('Workclass')
plt.ylabel('Income')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Education versus Income

# %%
# Sample DataFrame (replace this with your actual DataFrame)
df = pd.DataFrame({
    'Education': ['Bachelors', 'HS-grad', 'HS-grad', 'Bachelors', 'Masters'],
    'Income': ['<=50K', '>50K', '<=50K', '>50K', '<=50K']
})

# Visualization 2: Education vs Income
plt.figure(figsize=(10, 6))  # Create a new figure
sns.countplot(x='Education', hue='Income', data = newdata, order = newdata['Education'].value_counts().index)
plt.title('Income Distribution Across Education Levels')
plt.xlabel('Education')
plt.ylabel('Count')
plt.xticks(rotation = 45)
plt.show()  # Display the second plot

# %% [markdown]
# # Correlation heatmap of the numerical features

# %%
# Step 1: Filter only numerical columns from your DataFrame
numerical_data = newdata.select_dtypes(include=['float64', 'int64'])

# Step 2: Compute the correlation matrix for the numerical columns
correlation_matrix = numerical_data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                        Age    fnlwgt  Education Number  Capital Gain  \
# Age               1.000000 -0.075792          0.037623      0.079683
# fnlwgt           -0.075792  1.000000         -0.041968     -0.004107
# Education Number  0.037623 -0.041968          1.000000      0.126905
# Capital Gain      0.079683 -0.004107          0.126905      1.000000
# Capital Loss      0.059351 -0.004354          0.081718     -0.032102
# Hours per Week    0.101992 -0.018681          0.146210      0.083881
#
#                   Capital Loss  Hours per Week
# Age                   0.059351        0.101992
# fnlwgt               -0.004354       -0.018681
# Education Number      0.081718        0.146210
# Capital Gain         -0.032102        0.083881
# Capital Loss          1.000000        0.054195
# Hours per Week        0.054195        1.000000

# %%
# Encode Income column as binary
data_encode = data.copy()
data_encode['Income'] = data_encode['Income'].apply(lambda x: 1 if x == '>50K' else 0)
data_encode
# Out:
#        Age         Workclass  fnlwgt  Education  Education Number  \
# 0       50  Self-emp-not-inc   83311  Bachelors                13
# 1       38           Private  215646    HS-grad                 9
# 2       53           Private  234721       11th                 7
# 3       28           Private  338409  Bachelors                13
# 4       37           Private  284582    Masters                14
# ...    ...               ...     ...        ...               ...
# 48835   33           Private  245211  Bachelors                13
# 48836   39           Private  215419  Bachelors                13
# 48838   38           Private  374983  Bachelors                13
# 48839   44           Private   83891  Bachelors                13
# 48840   35      Self-emp-inc  182148  Bachelors                13
#
#            Marital Status         Occupation   Relationship  \
# 0      Married-civ-spouse    Exec-managerial        Husband
# ...

# %% [markdown]
# # Data Insight Generation

# %%
# Import necessary libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Filter only numerical columns

numerical_data = data_encode.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numerical_data.corr()

# Draw the heatmap
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Group by categorical features and calculate the mean income

categorical_columns = ['Workclass', 'Education', 'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native Country']

for column in categorical_columns:
    print(data_encode.groupby(column)['Income'].mean().sort_values(ascending=False))
    print("\n")
# Out:
# Workclass
# Self-emp-inc        0.554070
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.278978
# State-gov           0.267352
# Private             0.217702
# Without-pay         0.095238
# Name: Income, dtype: float64
#
#
# Education
# Prof-school     0.754140
# Doctorate       0.733456
# Masters         0.554097
# Bachelors       0.419871
# Assoc-acdm      0.264101
# Assoc-voc       0.257274
# Some-college    0.201030
# HS-grad         0.163431
# 12th            0.074523
# 10th            0.067048
# 7th-8th         0.066829
# 9th             0.056213
# 11th            0.054972
# 5th-6th         0.048998
# 1st-4th         0.036036
# Preschool       0.013889
# Name: Income, dtype: float64
#
#
# Marital Status
# Married-civ-spouse       0.454239
# Married-AF-spouse        0.437500
# Divorced                 0.104018
# Married-spouse-absent    0.097826
# Widowed                  0.094753
# Separated                0.070163
# ...
